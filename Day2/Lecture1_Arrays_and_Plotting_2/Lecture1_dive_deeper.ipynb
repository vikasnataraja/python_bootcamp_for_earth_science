# %% [markdown]
# # Day 2 — Lecture 1: Dive Deeper (optional)
#
# Optional extensions for NumPy and Matplotlib. **Not covered in the live lecture** — work through these during the afternoon block or when you want extra practice.
#
# **Before you start:** complete the core lesson in `Lecture1_lesson.ipynb`.
#
# Compare your work to `Lecture1_lesson_solutions.ipynb` when finished (solutions for these topics are in the original solutions notebook until a dedicated answer key is added).

# %% [markdown]
# ## Notebook structure
#
# <span style="color:red">Each section has a short reading link and a mini-challenge.</span> Fill in the code cell below each prompt.

# %% [markdown]
# ## Section 1 — NumPy extensions

# %% [markdown]
# ---
# ### <span style="color:red">Dive Deeper: `linspace` vs `arange` (optional)
#
# 📖 **Read:** [NumPy array creation](https://numpy.org/doc/stable/user/basics.creation.html)
#
# <span style="color:red">**Challenge:** Create the same 5 evenly spaced integers two ways; print both arrays and their `shape`.</span>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <span style="color:red">Dive Deeper: Stride slicing `arr[::n]` (optional)
#
# 📖 **Read:** [NumPy indexing — slicing and striding](https://numpy.org/doc/stable/user/basics.indexing.html#slicing-and-striding)
#
# <span style="color:red">**Challenge:** From `np.arange(10)`, extract every 2nd element and every 3rd element (two separate slices).</span>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <span style="color:red">Dive Deeper: `axis=` in `np.mean` (optional)
#
# 📖 **Read:** [NumPy aggregation basics](https://numpy.org/doc/stable/user/basics.aggregation.html#aggregation-basics)
#
# <span style="color:red">**Challenge:** On a 3×4 array, compute `np.mean(..., axis=0)` and `np.mean(..., axis=1)`. What does each result represent?</span>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <span style="color:red">Dive Deeper: Flip and transpose (optional)
#
# 📖 **Read:** [ndarray.T](https://numpy.org/doc/stable/reference/generated/numpy.ndarray.T.html)
#
# <span style="color:red">**Challenge:** Create a 2×3 array, flip it vertically with `np.flipud`, transpose with `.T`, and print shapes.</span>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <span style="color:red">Dive Deeper: `np.nan` and `np.nanmean` (optional)
#
# 📖 **Read:** [NumPy mathematical functions](https://numpy.org/doc/stable/reference/routines.math.html)
#
# <span style="color:red">**Challenge:** Create an array with one `np.nan`. Compare `np.mean` vs `np.nanmean`.</span>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <span style="color:red">Dive Deeper: `np.random` (optional)
#
# 📖 **Read:** [NumPy random sampling](https://numpy.org/doc/stable/reference/random/index.html)
#
# <span style="color:red">**Challenge:** Draw 20 random values with `np.random.rand(20)` and plot them as a line (preview of §2).</span>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <span style="color:red">Dive Deeper: Merge arrays (optional)
#
# 📖 **Read:** [numpy.concatenate](https://numpy.org/doc/stable/reference/generated/numpy.concatenate.html)
#
# <span style="color:red">**Challenge:** Stack two 1D arrays with `np.vstack` (vertical) and `np.hstack` (horizontal).</span>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <span style="color:red">Dive Deeper: `np.append` (optional)
#
# 📖 **Read:** [numpy.append](https://numpy.org/doc/stable/reference/generated/numpy.append.html)
#
# <span style="color:red">**Challenge:** Append a value to an array. Show why you must reassign: `arr = np.append(arr, 99)`.</span>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <span style="color:red">Dive Deeper: List ↔ array conversion (optional)
#
# 📖 **Read:** [NumPy absolute beginners — lists](https://numpy.org/doc/stable/user/absolute_beginners.html#how-to-convert-from-numpy-array-to-list)
#
# <span style="color:red">**Challenge:** Convert a numpy array to a Python list and back with `np.array()`. Print `type()` at each step.</span>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ## Section 2 — Matplotlib extensions
#
# Run `import matplotlib.pyplot as plt` and `import numpy as np` as needed.

# %% [markdown]
# ---
# ### <span style="color:red">Dive Deeper: `ax.scatter` (optional)
#
# 📖 **Read:** [matplotlib.axes.Axes.scatter](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.scatter.html)
#
# <span style="color:red">**Challenge:** Scatter two random 1D arrays (length 20). Add axis labels.</span>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <span style="color:red">Dive Deeper: Subplot grid layouts (optional)
#
# 📖 **Read:** [matplotlib.pyplot.subplots](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html)
#
# <span style="color:red">**Challenge:** Create a 2×3 subplot grid. Plot something simple in each panel.</span>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <span style="color:red">Dive Deeper: `imshow` and colorbars (optional)
#
# 📖 **Read:** [matplotlib.axes.Axes.imshow](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.imshow.html)
#
# <span style="color:red">**Challenge:** Plot a 10×10 `np.random.rand` heatmap with `cmap='inferno'` and a colorbar.</span>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <span style="color:red">Dive Deeper: Histograms (optional)
#
# 📖 **Read:** [matplotlib.axes.Axes.hist](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hist.html)
#
# <span style="color:red">**Challenge:** Histogram 1000 normal random values. Label the axes.</span>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <span style="color:red">Dive Deeper: Save figures (optional)
#
# 📖 **Read:** [matplotlib.pyplot.savefig](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html)
#
# <span style="color:red">**Challenge:** Save any plot from this notebook as `my_first_plot.png`.</span>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <span style="color:red">Dive Deeper: Pyplot vs object-oriented API (optional)
#
# 📖 **Read:** [Matplotlib quick start](https://matplotlib.org/stable/users/explain/quick_start.html)
#
# <span style="color:red">**Challenge:** Re-create one plot from this section using *only* `plt.plot()` (no `ax`). Compare the two styles.</span>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here
