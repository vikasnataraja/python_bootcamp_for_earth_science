# %% [markdown]
# # Day 2 — Lecture 1: Dive Deeper (optional)
#
# Optional extensions for NumPy and Matplotlib. **Not covered in the live lecture** — work through these during the afternoon block or when you want extra practice.
#
# **Before you start:** complete the core lesson in `Lecture1_lesson.ipynb`.
#
# Compare your work to `Lecture1_lesson_solutions.ipynb` when finished (solutions for these topics are in the original solutions notebook until a dedicated answer key is added).

# %% [markdown]
# ## Notebook structure
#
# <font color="#B91C1C">Each section has a short reading link and a mini-challenge.</font> Fill in the code cell below each prompt.

# %% [markdown]
# ## Section 1 — NumPy extensions

# %% [markdown]
# ---
# ### <font color="#B91C1C">Dive Deeper: `linspace` vs `arange` (optional)
#
# 📖 **Read:** [NumPy array creation](https://numpy.org/doc/stable/user/basics.creation.html)
#
# <font color="#B91C1C">**Challenge:** Create the same 5 evenly spaced integers two ways; print both arrays and their `shape`.</font>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <font color="#B91C1C">Dive Deeper: Stride slicing `arr[::n]` (optional)
#
# 📖 **Read:** [NumPy indexing — slicing and striding](https://numpy.org/doc/stable/user/basics.indexing.html#slicing-and-striding)
#
# <font color="#B91C1C">**Challenge:** From `np.arange(10)`, extract every 2nd element and every 3rd element (two separate slices).</font>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <font color="#B91C1C">Dive Deeper: `axis=` in `np.mean` (optional)
#
# 📖 **Read:** [NumPy aggregation basics](https://numpy.org/doc/stable/user/basics.aggregation.html#aggregation-basics)
#
# <font color="#B91C1C">**Challenge:** On a 3×4 array, compute `np.mean(..., axis=0)` and `np.mean(..., axis=1)`. What does each result represent?</font>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <font color="#B91C1C">Dive Deeper: Flip and transpose (optional)
#
# 📖 **Read:** [ndarray.T](https://numpy.org/doc/stable/reference/generated/numpy.ndarray.T.html)
#
# <font color="#B91C1C">**Challenge:** Create a 2×3 array, flip it vertically with `np.flipud`, transpose with `.T`, and print shapes.</font>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <font color="#B91C1C">Dive Deeper: `np.nan` and `np.nanmean` (optional)
#
# 📖 **Read:** [NumPy mathematical functions](https://numpy.org/doc/stable/reference/routines.math.html)
#
# <font color="#B91C1C">**Challenge:** Create an array with one `np.nan`. Compare `np.mean` vs `np.nanmean`.</font>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <font color="#B91C1C">Dive Deeper: `np.random` (optional)
#
# 📖 **Read:** [NumPy random sampling](https://numpy.org/doc/stable/reference/random/index.html)
#
# <font color="#B91C1C">**Challenge:** Draw 20 random values with `np.random.rand(20)` and plot them as a line (preview of §2).</font>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <font color="#B91C1C">Dive Deeper: Merge arrays (optional)
#
# 📖 **Read:** [numpy.concatenate](https://numpy.org/doc/stable/reference/generated/numpy.concatenate.html)
#
# <font color="#B91C1C">**Challenge:** Stack two 1D arrays with `np.vstack` (vertical) and `np.hstack` (horizontal).</font>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <font color="#B91C1C">Dive Deeper: `np.append` (optional)
#
# 📖 **Read:** [numpy.append](https://numpy.org/doc/stable/reference/generated/numpy.append.html)
#
# <font color="#B91C1C">**Challenge:** Append a value to an array. Show why you must reassign: `arr = np.append(arr, 99)`.</font>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <font color="#B91C1C">Dive Deeper: List ↔ array conversion (optional)
#
# 📖 **Read:** [NumPy absolute beginners — lists](https://numpy.org/doc/stable/user/absolute_beginners.html#how-to-convert-from-numpy-array-to-list)
#
# <font color="#B91C1C">**Challenge:** Convert a numpy array to a Python list and back with `np.array()`. Print `type()` at each step.</font>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ## Section 2 — Matplotlib extensions
#
# Run `import matplotlib.pyplot as plt` and `import numpy as np` as needed.

# %% [markdown]
# ---
# ### <font color="#B91C1C">Dive Deeper: `ax.scatter` (optional)
#
# 📖 **Read:** [matplotlib.axes.Axes.scatter](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.scatter.html)
#
# <font color="#B91C1C">**Challenge:** Scatter two random 1D arrays (length 20). Add axis labels.</font>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <font color="#B91C1C">Dive Deeper: Subplot grid layouts (optional)
#
# 📖 **Read:** [matplotlib.pyplot.subplots](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html)
#
# <font color="#B91C1C">**Challenge:** Create a 2×3 subplot grid. Plot something simple in each panel.</font>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <font color="#B91C1C">Dive Deeper: `imshow` and colorbars (optional)
#
# 📖 **Read:** [matplotlib.axes.Axes.imshow](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.imshow.html)
#
# <font color="#B91C1C">**Challenge:** Plot a 10×10 `np.random.rand` heatmap with `cmap='inferno'` and a colorbar.</font>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <font color="#B91C1C">Dive Deeper: Histograms (optional)
#
# 📖 **Read:** [matplotlib.axes.Axes.hist](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hist.html)
#
# <font color="#B91C1C">**Challenge:** Histogram 1000 normal random values. Label the axes.</font>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <font color="#B91C1C">Dive Deeper: Save figures (optional)
#
# 📖 **Read:** [matplotlib.pyplot.savefig](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html)
#
# <font color="#B91C1C">**Challenge:** Save any plot from this notebook as `my_first_plot.png`.</font>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here

# %% [markdown]
# ---
# ### <font color="#B91C1C">Dive Deeper: Pyplot vs object-oriented API (optional)
#
# 📖 **Read:** [Matplotlib quick start](https://matplotlib.org/stable/users/explain/quick_start.html)
#
# <font color="#B91C1C">**Challenge:** Re-create one plot from this section using *only* `plt.plot()` (no `ax`). Compare the two styles.</font>
#
# *Skip during lecture — try this afternoon if you want more practice.*
# ---

# %%
# Your code here
