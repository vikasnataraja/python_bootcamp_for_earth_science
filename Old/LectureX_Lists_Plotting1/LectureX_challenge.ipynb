# %%
# Path to shared bootcamp data (repo-root Datasets/)
DATA_FOLDER = "../../Datasets/"

# %% [markdown]
# # Day 1 — Lecture 0: Challenge (TBD)
#
# Challenge content TBD — will be a short lists + plotting drill using `DATA_FOLDER + "boco_air_temp.csv"` when Lecture0 merges into `Day1/`.
